# %% [markdown]
# ## **CS-5263 - Quantum Computing Basics**
# ## **Programming Assignment-1**

# %%
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit  #Importing the QuantumCircuit function from Qiskit. We will use this to create our quantum circuits!
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler, Estimator, Session

# We will use these functions to run our circuit and visualize its final state
from qiskit.visualization import *

import warnings  # We are using this library to suppress some warning messages
warnings.filterwarnings("ignore")

service = QiskitRuntimeService()
print("Libraries imported successfully!")
# Out:
# qiskit_runtime_service.__init__:INFO:2024-03-12 22:46:18,366: Default instance: ibm-q/open/main
# Libraries imported successfully!

# %% [markdown]
# **Exercise #1**
#
# **a) Create and draw a 1-qubit/1-classical bit circuit with 1 X, and a measurement at the end.**

# %%
# Define quantum circuit
qc = QuantumCircuit(1, 1)  # Creating a quantum circuit with 1 qubit and 1 classical bit

# Add gates here
qc.x(0)  # Apply X gate on qubit 0

# Measure here
qc.measure(0, 0)  # Measure qubit 0 and store the result in classical bit 0

# Draw here
qc.draw('mpl')  # Draw the quantum circuit

# %% [markdown]
# **b) Create and draw a 1-qubit/1-classical bit circuit with 1 X and 1 H gates, and a measurement at the end**

# %%
# Define quantum circuit
qc = QuantumCircuit(1, 1)  # Creating a quantum circuit with 1 qubit and 1 classical bit

# Add gates here
qc.x(0)  # Apply X gate on qubit 0
qc.h(0)  # Apply H gate on qubit 0

# Measure here
qc.measure(0, 0)  # Measure qubit 0 and store the result in classical bit 0

# Draw here
qc.draw('mpl')  # Draw the quantum circuit

# %% [markdown]
# **c) Create and draw 1-qubit/1-classical bit circuit with in the order of gates (X , H , Z , X , H) and a measurement at the end.**

# %%
# Define quantum circuit
qc = QuantumCircuit(1, 1)  # Creating a quantum circuit with 1 qubit and 1 classical bit

# Add gates here
qc.x(0)  # Apply X gate on qubit 0
qc.h(0)  # Apply H gate on qubit 0
qc.z(0)  # Apply Z gate on qubit 0
qc.x(0)  # Apply X gate on qubit 0
qc.h(0)  # Apply H gate on qubit 0

# Measure here
qc.measure(0, 0)  # Measure qubit 0 and store the result in classical bit 0

# Draw here
qc.draw('mpl')  # Draw the quantum circuit

# %% [markdown]
# **Run the code below to simulate the measurement results using QASM.**

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = qc)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 22:49:09,573: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **Exercise#2**
#
# **a) Create and draw a 2-qubit/2-classical bit circuit gates applied as described below and a measurement at the end.**
#
# **Gates**:
#
# H on qubit 0
#
# H on qubit 1
#
# CX with qubit 0 as the control and qubit 1 as the target

# %%
# Define quantum circuit
qc = QuantumCircuit(2, 2)  # Creating a quantum circuit with 2 qubits and 2 classical bits

# Gates
qc.h(0)  # Apply H gate on qubit 0
qc.h(1)  # Apply H gate on qubit 1
qc.cx(0, 1)  # Apply CX gate with qubit 0 as control and qubit 1 as target

# Measure
qc.measure([0, 1], [0, 1])  # Measure qubit 0 and qubit 1, store the results in classical bit 0 and classical bit 1

# Draw
qc.draw('mpl')  # Draw the quantum circuit

# %% [markdown]
# **Complete the code below to simulate the measurement results using QASM ( same as in Exercise 1)**

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = qc)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 22:50:28,812: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **b) Create and draw a 2-qubit/2-classical bit circuit gates applied as described below and a measurement at the end. Then, simulate this circuit using the code provided.**
#
# **Gates**
#
# X on qubit 1
#
# H on qubit 0
#
# CX with control as 1 and target as 0
#
# SWAP gate for 0 and 1 qubit.

# %%
# Define quantum circuit
qc = QuantumCircuit(2, 2)  # Creating a quantum circuit with 2 qubits and 2 classical bits

# Gates
qc.x(1)  # Apply X gate on qubit 1
qc.h(0)  # Apply H gate on qubit 0
qc.cx(1, 0)  # Apply CX gate with qubit 1 as control and qubit 0 as target
qc.swap(0, 1)  # Apply SWAP gate between qubit 0 and qubit 1

# Measure
qc.measure([0, 1], [0, 1])  # Measure qubit 0 and qubit 1, store the results in classical bit 0 and classical bit 1

# Draw
qc.draw('mpl')  # Draw the quantum circuit

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = qc)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 22:51:35,877: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **Exercise #3**
#
# **a) Create and draw a 2-qubit/2-classical bit circuit gates applied as described below and a measurement at the end. Then, simulate this circuit using the code provided.**
#
# **Gates**:
#
# H on qubit 0
#
# H on qubit 1
#
# CX with qubit 0 as the control and qubit 1 as the target
#
# H on qubit 0
#
# H on qubit 1

# %%
# Define quantum circuit
qc = QuantumCircuit(2, 2)  # Creating a quantum circuit with 2 qubits and 2 classical bits

# Gates
qc.h(0)  # Apply H gate on qubit 0
qc.h(1)  # Apply H gate on qubit 1
qc.cx(0, 1)  # Apply CX gate with qubit 0 as control and qubit 1 as target
qc.h(0)  # Apply H gate on qubit 0
qc.h(1)  # Apply H gate on qubit 1

# Measure
qc.measure([0, 1], [0, 1])  # Measure qubit 0 and qubit 1, store the results in classical bit 0 and classical bit 1

# Draw
qc.draw('mpl')  # Draw the quantum circuit

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = qc)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 22:52:43,454: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **b) Create and draw a 2-qubit/2-classical bit circuit gates applied as described below and a measurement at the end. Then, simulate this circuit using the code provided.**
#
# **Gates:**
#
# CX with qubit 0 as the control and qubit 1 as the target

# %%
# Define quantum circuit
qc = QuantumCircuit(2, 2)  # Creating a quantum circuit with 2 qubits and 2 classical bits

# Gates
qc.cx(0, 1)  # Apply CX gate with qubit 0 as control and qubit 1 as target

# Measure
qc.measure([0, 1], [0, 1])  # Measure qubit 0 and qubit 1, store the results in classical bit 0 and classical bit 1

# Draw
qc.draw('mpl')  # Draw the quantum circuit

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = qc)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 22:54:12,713: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **c) After geting the results for exercise 3a and 3b, obersrve them carefully, and mention what you deduce below.**

# %% [markdown]
# **In exercise 3a,** the circuit consists of a series of Hadamard (H) gates and a controlled-X (CX) gate. The Hadamard gates create superposition states, and the CX gate introduces entanglement between qubit 0 and qubit 1. The final measurement in the computational basis collapses the superposition, and the results obtained through simulation represent the possible outcomes.
#
# **In exercise 3b,** the circuit consists of a single controlled-X (CX) gate. This gate creates entanglement between qubit 0 (control) and qubit 1 (target). The final measurement in the computational basis reveals the entangled state of the qubits.
#
# **Observations:**
#
# **Exercise 3a:** Outcomes where classical bits 0 and 1 exhibit correlated results due to entanglement created by the CX gate. The Hadamard gates before and after the CX gate contribute to the overall quantum state.
#
# **Exercise 3b:** The outcomes also show correlations between classical bits 0 and 1, indicating the entangled state created by the CX gate. However, the absence of Hadamard gates before and after the CX gate means that the circuit is simpler compared to 3a.

# %% [markdown]
# **Exercise #4**
#
# **a) Create and draw a 2-qubit/2-classical bit circuit with the help of following inputs and outputs . Simulate them with shots = 2048**
#
# Inputs-->Outputs
#
# |00> ---> |00>
#
# |01> ---> |11>
#
# |10> ---> |01>
#
# |11> ---> |10>

# %%
# Define quantum circuit
qc = QuantumCircuit(2, 2)  # Creating a quantum circuit with 2 qubits and 2 classical bits

# Inputs --> Outputs
# |00> ---> |00>
# |01> ---> |11>
# |10> ---> |01>
# |11> ---> |10>

# For flipping input qubits
qc.x(0)  # Apply X gate on qubit 0 to flip from |0> to |1>
qc.x(1)  # Apply X gate on qubit 1 to flip from |0> to |1>

# Gates
# No additional gates needed for this exercise

# Measure
qc.measure([0, 1], [0, 1])  # Measure qubit 0 and qubit 1, store the results in classical bit 0 and classical bit 1

# Draw
qc.draw('mpl')  # Draw the quantum circuit

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = qc)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 22:59:41,529: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **b)Create and draw a 2-qubit/2-classical bit circuit with the help of following inputs and outputs . Simulate them with shots = 2048**
#
# Inputs-->Outputs
#
# |00> ---> |11>
#
# |01> ---> |00>
#
# |10> ---> |10>
#
# |11> ---> |01>

# %%
# Define quantum circuit
qc = QuantumCircuit(2, 2)  # Creating a quantum circuit with 2 qubits and 2 classical bits

# Inputs --> Outputs
# |00> ---> |11>
# |01> ---> |00>
# |10> ---> |10>
# |11> ---> |01>

# For flipping input qubits
qc.x(0)  # Apply X gate on qubit 0 to flip from |0> to |1>
qc.x(1)  # Apply X gate on qubit 1 to flip from |0> to |1>

# Gates
# No additional gates needed for this exercise

# Measure
qc.measure([0, 1], [0, 1])  # Measure qubit 0 and qubit 1, store the results in classical bit 0 and classical bit 1

# Draw
qc.draw('mpl')  # Draw the quantum circuit

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = qc)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 23:00:18,183: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **Exercise #5**
#
# **a) Create and draw a 3-qubit/3-classical bit circuit gates applied as described below and a measurement at the end. Then, simulate this circuit using the code provided.**
#
# **Gates**:
#
# H on qubit 0
#
# H on qubit 1
#
# CX with qubit 0 as the control and qubit 1 as the target
#
# CX with qubit 1 as the control and qubit 2 as the target
#
# CX with qubit 2 as the control and qubit 0 as the target

# %%
# Define quantum circuit
qc = QuantumCircuit(3, 3)  # Creating a quantum circuit with 3 qubits and 3 classical bits

# Gates
qc.h(0)  # Apply H gate on qubit 0
qc.h(1)  # Apply H gate on qubit 1
qc.cx(0, 1)  # Apply CX gate with qubit 0 as control and qubit 1 as target
qc.cx(1, 2)  # Apply CX gate with qubit 1 as control and qubit 2 as target
qc.cx(2, 0)  # Apply CX gate with qubit 2 as control and qubit 0 as target

# Measure
qc.measure([0, 1, 2], [0, 1, 2])  # Measure qubit 0, qubit 1, and qubit 2, store the results in classical bit 0, 1, and 2

# Draw
qc.draw('mpl')  # Draw the quantum circuit

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = qc)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 23:01:05,057: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **b) Create and draw a 3-qubit/3-classical bit circuit gates applied as described below and a measurement at the end. Then, simulate this circuit using the code provided.**
#
# **Gates**:
#
# X on qubit 0
#
# H on qubit 1
#
# X on qubit 2
#
# CCX with qubit 0,1 as the control and qubit 2 as the target
#
# CX with qubit 0 as the control and qubit 2 as the target
#
# CSWAP with 2 as control and swap the Qubits 0 and 1
#
# CCX with qubit 1,2 as the control and qubit 0 as the target

# %%
# Define quantum circuit
qc = QuantumCircuit(3, 3)  # Creating a quantum circuit with 3 qubits and 3 classical bits

# Gates
qc.x(0)  # Apply X gate on qubit 0
qc.h(1)  # Apply H gate on qubit 1
qc.x(2)  # Apply X gate on qubit 2
qc.ccx(0, 1, 2)  # Apply CCX gate with qubit 0,1 as control and qubit 2 as target
qc.cx(0, 2)  # Apply CX gate with qubit 0 as control and qubit 2 as target
qc.cswap(2, 0, 1)  # Apply CSWAP gate with qubit 2 as control and swap qubit 0 and qubit 1
qc.ccx(1, 2, 0)  # Apply CCX gate with qubit 1,2 as control and qubit 0 as target

# Measure
qc.measure([0, 1, 2], [0, 1, 2])  # Measure qubit 0, qubit 1, and qubit 2, store the results in classical bit 0, 1, and 2

# Draw
qc.draw('mpl')  # Draw the quantum circuit

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = qc)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 23:01:52,744: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **c) Code the circuit for all the bell states expalined in the class and simulate each of the following.**
#
# Note:- This part consists of 4 different circuits. You need to write the code the 4 different circuits.
#
# Hint:- As all qubits starts with |0>, use X gate to change to |1>.

# %%
# Define quantum circuit for Bell State 1
bell_circuit_1 = QuantumCircuit(2, 2)

# Apply Hadamard gate on qubit 0
bell_circuit_1.h(0)

# Apply CNOT gate with qubit 0 as control and qubit 1 as target
bell_circuit_1.cx(0, 1)

# Measure
bell_circuit_1.measure([0, 1], [0, 1])

# Draw
bell_circuit_1.draw('mpl')

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = bell_circuit_1)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 23:03:12,633: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %%
# Define quantum circuit for Bell State 2
bell_circuit_2 = QuantumCircuit(2, 2)

# Apply Hadamard gate on qubit 0
bell_circuit_2.h(0)

# Apply X gate on qubit 1
bell_circuit_2.x(1)

# Apply CNOT gate with qubit 0 as control and qubit 1 as target
bell_circuit_2.cx(0, 1)

# Measure
bell_circuit_2.measure([0, 1], [0, 1])

# Draw
bell_circuit_2.draw('mpl')

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = bell_circuit_2)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 23:04:17,165: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %%
# Define quantum circuit for Bell State 3
bell_circuit_3 = QuantumCircuit(2, 2)

# Apply X gate on qubit 0
bell_circuit_3.x(0)

# Apply Hadamard gate on qubit 0
bell_circuit_3.h(0)

# Apply CNOT gate with qubit 0 as control and qubit 1 as target
bell_circuit_3.cx(0, 1)

# Measure
bell_circuit_3.measure([0, 1], [0, 1])

# Draw
bell_circuit_3.draw('mpl')

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = bell_circuit_3)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 23:04:56,243: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %%
# Define quantum circuit for Bell State 4
bell_circuit_4 = QuantumCircuit(2, 2)

# Apply X gate on qubit 0
bell_circuit_4.x(0)

# Apply Hadamard gate on qubit 0
bell_circuit_4.h(0)

# Apply X gate on qubit 1
bell_circuit_4.x(1)

# Apply CNOT gate with qubit 0 as control and qubit 1 as target
bell_circuit_4.cx(0, 1)

# Measure
bell_circuit_4.measure([0, 1], [0, 1])

# Draw
bell_circuit_4.draw('mpl')

# %%
# Simulate using Simulator
backend = service.get_backend('ibmq_qasm_simulator')

with Session(service = service, backend = backend) as session:
    sampler = Sampler()
    job = sampler.run(circuits = bell_circuit_4)
    
job.result()    
plot_histogram(job.result().quasi_dists[0].binary_probabilities())
# Out:
# base_primitive._run_primitive:INFO:2024-03-12 23:05:27,473: Submitting job using options {'optimization_level': 1, 'resilience_level': 0, 'transpilation': {'skip_transpilation': False, 'optimization_settings': {'level': 1}}, 'resilience': {'level': 0}, 'execution': {'shots': 4000, 'init_qubits': True}, 'environment': {'log_level': 'WARNING'}, 'simulator': {'noise_model': Unset, 'seed_simulator': Unset, 'coupling_map': Unset, 'basis_gates': Unset}}

# %% [markdown]
# **Exercise 6**
#
#
# **a)Create and draw a 6-qubit/6-classical bit quantum circuit where you apply an X followed by H gate to each qubit using a for loop and measure all the bits.**

# %%
# Define quantum circuit
qc = QuantumCircuit(6, 6)  # Creating a quantum circuit with 6 qubits and 6 classical bits

# Apply X followed by H gate to each qubit using a for loop
for qubit in range(6):
    qc.x(qubit)  # Apply X gate on the current qubit
    qc.h(qubit)  # Apply H gate on the current qubit

# Measure all qubits
qc.measure(range(6), range(6))  # Measure qubits 0 to 5 and store the results in classical bits 0 to 5

# Draw
qc.draw('mpl')

# %% [markdown]
# **b) Create and draw a 5-qubit/5-classical bit quantum circuit where you apply the gates listed below using a loop and measure.**
#
# H gate on qubit 0
#
# CX with qubit 0 as the control and qubit 1 as the target
#
# H gate on qubit 1
#
# CX with qubit 1 as the control and qubit 2 as the target
#
# H gate on qubit 2
#
# CX with qubit 2 as the control and qubit 3 as the target

# %%
# Define quantum circuit
qc = QuantumCircuit(5, 5)  # Creating a quantum circuit with 5 qubits and 5 classical bits

# Apply H gate and CX gate using a loop
for qubit in range(4):
    qc.h(qubit)         # Apply H gate on the current qubit
    qc.cx(qubit, qubit+1)  # Apply CX gate with the current qubit as control and the next qubit as target

# Apply H gate on the last qubit
qc.h(4)

# Measure all qubits
qc.measure(range(5), range(5))  # Measure qubits 0 to 4 and store the results in classical bits 0 to 4

# Draw
qc.draw('mpl')

# %% [markdown]
# ## The End
